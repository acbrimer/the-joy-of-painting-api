# %%
import pandas as pd
import os

DATA_ROOT = os.path.join(os.getcwd(), 'data')
SOURCE_FILES = ['The Joy Of Painiting - Colors Used',
                'The Joy Of Painiting - Subject Matter', 'The Joy Of Painting - Episode Dates']

df_colors_used = pd.read_csv(os.path.join(
    DATA_ROOT, 'The Joy Of Painiting - Colors Used'))
df_subject_matter = pd.read_csv(os.path.join(
    DATA_ROOT, 'The Joy Of Painiting - Subject Matter'))
df_episode_dates = pd.read_csv(os.path.join(
    DATA_ROOT, 'The Joy Of Painting - Episode Dates'), delimiter="\t", header=None)

# %%
print("The Joy Of Painiting - Colors Used:")
df_colors_used.head()
# Out:
# The Joy Of Painiting - Colors Used:
#    Unnamed: 0  painting_index  \
# 0           1             282
# 1           2             283
# 2           3             284
# 3           4             285
# 4           5             286
#
#                                              img_src       painting_title  \
# 0  https://www.twoinchbrush.com/images/painting28...  A Walk in the Woods
# 1  https://www.twoinchbrush.com/images/painting28...         Mt. McKinley
# 2  https://www.twoinchbrush.com/images/painting28...         Ebony Sunset
# 3  https://www.twoinchbrush.com/images/painting28...          Winter Mist
# 4  https://www.twoinchbrush.com/images/painting28...         Quiet Stream
#
#    season  episode  num_colors                                youtube_src  \
# 0       1        1           8  https://www.youtube.com/embed/oh5p5f5_-7A
# 1       1        2           8  https://www.youtube.com/embed/RInDWhYceLU
# ...

# %%
print("The Joy Of Painiting - Subject Matter:")
df_subject_matter.head()
# Out:
# The Joy Of Painiting - Subject Matter:
#   EPISODE                  TITLE  APPLE_FRAME  AURORA_BOREALIS  BARN  BEACH  \
# 0  S01E01  "A WALK IN THE WOODS"            0                0     0      0
# 1  S01E02         "MT. MCKINLEY"            0                0     0      0
# 2  S01E03         "EBONY SUNSET"            0                0     0      0
# 3  S01E04          "WINTER MIST"            0                0     0      0
# 4  S01E05         "QUIET STREAM"            0                0     0      0
#
#    BOAT  BRIDGE  BUILDING  BUSHES  ...  TOMB_FRAME  TREE  TREES  TRIPLE_FRAME  \
# 0     0       0         0       1  ...           0     1      1             0
# 1     0       0         0       0  ...           0     1      1             0
# 2     0       0         0       0  ...           0     1      1             0
# 3     0       0         0       1  ...           0     1      1             0
# 4     0       0         0       0  ...           0     1      1             0
#
# ...

# %%
print("The Joy Of Painiting - Episode Dates:")
df_episode_dates.head()
# Out:
# The Joy Of Painiting - Episode Dates:
#                                         0
# 0  A Walk in the Woods (January 11, 1983)
# 1       Mount McKinley (January 11, 1983)
# 2         Ebony Sunset (January 18, 1983)
# 3          Winter Mist (January 25, 1983)
# 4         Quiet Stream (February 1, 1983)
